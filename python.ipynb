# %%
pip install pandas flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m pip install --upgrade pandas flask pip
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------------------------- ---- 1.6/1.8 MB 16.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 6.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
# ...

# %%
import pandas
import flask

print(pandas.__version__)
print(flask.__version__)
# Out:
# 2.3.3
# 3.1.2
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_10248\2668393686.py:5: DeprecationWarning: The '__version__' attribute is deprecated and will be removed in Flask 3.2. Use feature detection or 'importlib.metadata.version("flask")' instead.
#   print(flask.__version__)
